# %% [markdown]
# <a href="https://colab.research.google.com/github/nomo82/python/blob/main/Pivot_Tableipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importar librerias
import pandas as pd
import numpy as np

# %%
#Conectar al Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Usemos el metodo pivot y traemos el nuevo archivo supermarket_sales
#Traemos el mismo archivo
df_supermarket=pd.read_excel('/content/drive/MyDrive/Alexander Niño.lnk/2025/_Python/supermarket_sales.xlsx')
df_supermarket.head(5)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#        Time      Payment    cogs  gross margin percentage  gross income  \
# 0  13:08:00      Ewallet  522.83                 4.761905       26.1415
# ...

# %%
#Vamos a relaizar una tabla pivot sumando los registros. Observaremos en compra mas por genero
#Vamos a usar dentro del metodo 'pivot_table' un argumento que es rarto y se llama aggfunc = que me ayuda
#Vamos a contar
df_supermarket.pivot_table(index='Gender', aggfunc='count')
# Out:
#         Branch  City  Customer type  Date  Invoice ID  Payment  Product line  \
# Gender
# Female     501   501            501   501         501      501           501
# Male       499   499            499   499         499      499           499
#
#         Quantity  Rating  Tax 5%  Time  Total  Unit price  cogs  gross income  \
# Gender
# Female       501     501     501   501    501         501   501           501
# Male         499     499     499   499    499         499   499           499
#
#         gross margin percentage
# Gender
# Female                      501
# Male                        499

# %%
#Ahora lo que vamos a ralizar es sumar en cada columna ppor género. Sin embargo tener presente que solo puedo sumar nuemros
df_supermarket.pivot_table(
    index='Gender',  # Agrupar por género
    values=['Quantity', 'Rating', 'Tax 5%', 'Total', 'Unit price', 'cogs', 'gross income', 'gross margin percentage'],  # Columnas a agregar
    aggfunc='sum'    # Función de agregación (suma)
)
# Out:
#         Quantity  Rating    Tax 5%       Total  Unit price       cogs  \
# Gender
# Female      2869  3489.2  7994.425  167882.925    27687.24  159888.50
# Male        2641  3483.5  7384.944  155083.824    27984.89  147698.88
#
#         gross income  gross margin percentage
# Gender
# Female      7994.425              2385.714286
# Male        7384.944              2376.190476
