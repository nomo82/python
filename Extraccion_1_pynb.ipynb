# %% [markdown]
# <a href="https://colab.research.google.com/github/nomo82/python/blob/main/Extraccion_1_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# La extracción o seleccionde datos se puede realizar con fos metodos 1 Metodo Loc y el metodo iloc
# loc debemos especificar el nombre de la fila o el nombre de la columna
# iloc debemos especificar la pocisión tal cual haciamos con las listas donde el primer dato inicia en 0

# %%
#Importar librerias Pandas
import pandas as pd

# %%
#Conectar a Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Leer el archivo CSV palyers 20.csv
df_jugadores=pd.read_csv('/content/drive/MyDrive/Alexander Niño.lnk/2025/_Python/players_20.csv')
df_jugadores.head(10)
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
# 5     192985  https://sofifa.com/player/192985/kevin-de-bruy...
# 6     192448  https://sofifa.com/player/192448/marc-andre-te...
# 7     203376  https://sofifa.com/player/203376/virgil-van-di...
# 8     177003  https://sofifa.com/player/177003/luka-modric/2...
# 9     209331  https://sofifa.com/player/209331/mohamed-salah...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# ...

# %%
#Vamos a fijar el nombre
df_jugadores.set_index('short_name')
# Out:
#                    sofifa_id  \
# short_name
# L. Messi              158023
# Cristiano Ronaldo      20801
# Neymar Jr             190871
# J. Oblak              200389
# E. Hazard             183277
# ...                      ...
# Shao Shuai            245006
# Xiao Mingjie          250995
# Zhang Wei             252332
# Wang Haijian          251110
# Pan Ximing            233449
#
#                                                           player_url  \
# short_name
# L. Messi           https://sofifa.com/player/158023/lionel-messi/...
# Cristiano Ronaldo  https://sofifa.com/player/20801/c-ronaldo-dos-...
# Neymar Jr          https://sofifa.com/player/190871/neymar-da-sil...
# J. Oblak           https://sofifa.com/player/200389/jan-oblak/20/...
# E. Hazard          https://sofifa.com/player/183277/eden-hazard/2...
# ...                                                              ...
# Shao Shuai         https://sofifa.com/player/245006/shuai-shao/20...
# ...

# %%
#Vamos a sobreescribir el DF para ajustar los cambios de la columna ''short_name'
df_jugadores=df_jugadores.set_index('short_name')

# %%
df_jugadores
# Out:
#                    sofifa_id  \
# short_name
# L. Messi              158023
# Cristiano Ronaldo      20801
# Neymar Jr             190871
# J. Oblak              200389
# E. Hazard             183277
# ...                      ...
# Shao Shuai            245006
# Xiao Mingjie          250995
# Zhang Wei             252332
# Wang Haijian          251110
# Pan Ximing            233449
#
#                                                           player_url  \
# short_name
# L. Messi           https://sofifa.com/player/158023/lionel-messi/...
# Cristiano Ronaldo  https://sofifa.com/player/20801/c-ronaldo-dos-...
# Neymar Jr          https://sofifa.com/player/190871/neymar-da-sil...
# J. Oblak           https://sofifa.com/player/200389/jan-oblak/20/...
# E. Hazard          https://sofifa.com/player/183277/eden-hazard/2...
# ...                                                              ...
# Shao Shuai         https://sofifa.com/player/245006/shuai-shao/20...
# ...

# %%
#Vamos a traer las columnas que necesito y voy actualizar el DF
df_jugadores=df_jugadores[['player_url', 'long_name',	'age', 'dob',	'height_cm',	'weight_kg', 'nationality',	'club']]
df_jugadores
# Out:
#                                                           player_url  \
# short_name
# L. Messi           https://sofifa.com/player/158023/lionel-messi/...
# Cristiano Ronaldo  https://sofifa.com/player/20801/c-ronaldo-dos-...
# Neymar Jr          https://sofifa.com/player/190871/neymar-da-sil...
# J. Oblak           https://sofifa.com/player/200389/jan-oblak/20/...
# E. Hazard          https://sofifa.com/player/183277/eden-hazard/2...
# ...                                                              ...
# Shao Shuai         https://sofifa.com/player/245006/shuai-shao/20...
# Xiao Mingjie       https://sofifa.com/player/250995/mingjie-xiao/...
# Zhang Wei          https://sofifa.com/player/252332/wei-zhang/20/...
# Wang Haijian       https://sofifa.com/player/251110/haijian-wang/...
# Pan Ximing         https://sofifa.com/player/233449/ximing-pan/20...
#
#                                              long_name  age         dob  \
# short_name
# ...

# %%
#Vamos a usar el metodo 'loc()'
df_jugadores.loc['Cristiano Ronaldo']
# Out:
# player_url     https://sofifa.com/player/20801/c-ronaldo-dos-...
# long_name                    Cristiano Ronaldo dos Santos Aveiro
# age                                                           34
# dob                                                   1985-02-05
# height_cm                                                    187
# weight_kg                                                     83
# nationality                                             Portugal
# club                                                    Juventus
# Name: Cristiano Ronaldo, dtype: object

# %%
#Ahora traemos los datos de Neymar Jr
df_jugadores.loc['Neymar Jr']
# Out:
# player_url     https://sofifa.com/player/190871/neymar-da-sil...
# long_name                          Neymar da Silva Santos Junior
# age                                                           27
# dob                                                   1992-02-05
# height_cm                                                    175
# weight_kg                                                     68
# nationality                                               Brazil
# club                                         Paris Saint-Germain
# Name: Neymar Jr, dtype: object

# %%
#Vamos a traer al goato de Messi
df_jugadores.loc['L. Messi', 'club']
# Out:
# 'FC Barcelona'

# %%
#Vamos a traer E. Hazard
df_jugadores.loc['E. Hazard', 'club']
# Out:
# 'Real Madrid'

# %%
#Vamos a traer a Pan Ximing
df_jugadores.loc['Pan Ximing', 'club']
# Out:
# 'Hebei China Fortune FC'

# %%
#Ahora este metodo de log tambien nos sirve para obtener todos los datos de una columna
df_jugadores.loc [:, 'age']
# Out:
# short_name
# L. Messi             32
# Cristiano Ronaldo    34
# Neymar Jr            27
# J. Oblak             26
# E. Hazard            28
#                      ..
# Shao Shuai           22
# Xiao Mingjie         22
# Zhang Wei            19
# Wang Haijian         18
# Pan Ximing           26
# Name: age, Length: 18278, dtype: int64

# %%
df_jugadores.loc [:, 'weight_kg']
# Out:
# short_name
# L. Messi             72
# Cristiano Ronaldo    83
# Neymar Jr            68
# J. Oblak             87
# E. Hazard            74
#                      ..
# Shao Shuai           79
# Xiao Mingjie         66
# Zhang Wei            75
# Wang Haijian         74
# Pan Ximing           78
# Name: weight_kg, Length: 18278, dtype: int64

# %%
#Vamos a traer los datos todo un jugador o campo especifico
df_jugadores['Xiao Mingjie']

# %%
#Vamos a traer todos los datos de un jugador
df_jugadores.loc[['Neymar Jr', 'Cristiano Ronaldo']]
# Out:
#                                                           player_url  \
# short_name
# Neymar Jr          https://sofifa.com/player/190871/neymar-da-sil...
# Cristiano Ronaldo  https://sofifa.com/player/20801/c-ronaldo-dos-...
#
#                                              long_name  age         dob  \
# short_name
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
#
#                    height_cm  weight_kg nationality                 club
# short_name
# Neymar Jr                175         68      Brazil  Paris Saint-Germain
# Cristiano Ronaldo        187         83    Portugal             Juventus

# %%
#Vamos a traer todos los datos de un jugador y la altura para detrerminar quien es mas alto
df_jugadores.loc[['Cristiano Ronaldo', 'L. Messi'], 'height_cm']
# Out:
# short_name
# Cristiano Ronaldo    187
# L. Messi             170
# Name: height_cm, dtype: int64

# %%
#Ahora podeemos traer dos columnas con dos filas o mas datos
df_jugadores.loc[['Cristiano Ronaldo', 'L. Messi'], ['club','height_cm']]
# Out:
#                            club  height_cm
# short_name
# Cristiano Ronaldo      Juventus        187
# L. Messi           FC Barcelona        170

# %%
#Bamos a cambiar los datos
df_jugadores.loc[['Cristiano Ronaldo', 'Neymar Jr'], ['club','height_cm']]
# Out:
#                                   club  height_cm
# short_name
# Cristiano Ronaldo             Juventus        187
# Neymar Jr          Paris Saint-Germain        175

# %%
df_jugadores.loc[['E. Hazard', 'Sergio Ramos'], ['club','nationality']]
# Out:
#                      club nationality
# short_name
# E. Hazard     Real Madrid     Belgium
# Sergio Ramos  Real Madrid       Spain

# %%
#Ahora usamos el metodo de slicing para cortar datos del DF que yo seleccione
jugadores=['Cristiano Ronaldo', 'L. Messi']

#Ahora hacemoos el slicing
df_jugadores.loc[jugadores, 'age':'weight_kg']
# Out:
#                    age         dob  height_cm  weight_kg
# short_name
# Cristiano Ronaldo   34  1985-02-05        187         83
# L. Messi            32  1987-06-24        170         72

# %%
#Ahora usamos el metodo de slicing para cortar datos del DF que yo seleccione
jugadores=['Cristiano Ronaldo', 'J. Oblak', 'L. Messi', 'Sergio Ramos']

#Ahora hacemoos el slicing
df_jugadores.loc[jugadores, 'long_name':'nationality']
# Out:
#                                              long_name  age         dob  \
# short_name
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Sergio Ramos                       Sergio Ramos García   33  1986-03-30
#
#                    height_cm  weight_kg nationality
# short_name
# Cristiano Ronaldo        187         83    Portugal
# J. Oblak                 188         87    Slovenia
# L. Messi                 170         72   Argentina
# Sergio Ramos             184         82       Spain

# %%
#Ahora si deseo llamaar el Top 10 de jugadores
df_jugadores.index[:10]
# Out:
# Index(['L. Messi', 'Cristiano Ronaldo', 'Neymar Jr', 'J. Oblak', 'E. Hazard',
#        'K. De Bruyne', 'M. ter Stegen', 'V. van Dijk', 'L. Modrić',
#        'M. Salah'],
#       dtype='object', name='short_name')

# %%
#Si deseo llamar todos los datos de esos 10 jugadores lo que debo hacer es usar el metodo .loc y creando una variable de columnas
columnas=['age', 'dob',	'height_cm', 'weight_kg',	'nationality', 'club']
df_jugadores.loc['L. Messi': 'M. Salah', columnas]
# Out:
#                    age         dob  height_cm  weight_kg  nationality  \
# short_name
# L. Messi            32  1987-06-24        170         72    Argentina
# Cristiano Ronaldo   34  1985-02-05        187         83     Portugal
# Neymar Jr           27  1992-02-05        175         68       Brazil
# J. Oblak            26  1993-01-07        188         87     Slovenia
# E. Hazard           28  1991-01-07        175         74      Belgium
# K. De Bruyne        28  1991-06-28        181         70      Belgium
# M. ter Stegen       27  1992-04-30        187         85      Germany
# V. van Dijk         27  1991-07-08        193         92  Netherlands
# L. Modrić           33  1985-09-09        172         66      Croatia
# M. Salah            27  1992-06-15        175         71        Egypt
#
#                                   club
# short_name
# L. Messi                  FC Barcelona
# Cristiano Ronaldo             Juventus
# Neymar Jr          Paris Saint-Germain
# ...

# %%
#Ahora si deseo llamaar el Top 20 de jugadores
df_jugadores.index[:21]
# Out:
# Index(['L. Messi', 'Cristiano Ronaldo', 'Neymar Jr', 'J. Oblak', 'E. Hazard',
#        'K. De Bruyne', 'M. ter Stegen', 'V. van Dijk', 'L. Modrić', 'M. Salah',
#        'K. Mbappé', 'K. Koulibaly', 'H. Kane', 'Alisson', 'De Gea', 'N. Kanté',
#        'G. Chiellini', 'S. Agüero', 'Sergio Ramos', 'L. Suárez',
#        'R. Lewandowski'],
#       dtype='object', name='short_name')

# %%
columnas=['age', 'dob',	'height_cm', 'weight_kg',	'nationality', 'club']
df_jugadores.loc['L. Messi': 'R. Lewandowski', columnas]
# Out:
#                    age         dob  height_cm  weight_kg  nationality  \
# short_name
# L. Messi            32  1987-06-24        170         72    Argentina
# Cristiano Ronaldo   34  1985-02-05        187         83     Portugal
# Neymar Jr           27  1992-02-05        175         68       Brazil
# J. Oblak            26  1993-01-07        188         87     Slovenia
# E. Hazard           28  1991-01-07        175         74      Belgium
# K. De Bruyne        28  1991-06-28        181         70      Belgium
# M. ter Stegen       27  1992-04-30        187         85      Germany
# V. van Dijk         27  1991-07-08        193         92  Netherlands
# L. Modrić           33  1985-09-09        172         66      Croatia
# M. Salah            27  1992-06-15        175         71        Egypt
# K. Mbappé           20  1998-12-20        178         73       France
# K. Koulibaly        28  1991-06-20        187         89      Senegal
# ...

# %% [markdown]
# Ahora vamos a ver el metodo con condiciones

# %%
#Vamos a realizar las condiciones
columnas=['age', 'dob',	'height_cm', 'weight_kg',	'nationality', 'club']
df_jugadores['height_cm']>100
# Out:
# short_name
# L. Messi             True
# Cristiano Ronaldo    True
# Neymar Jr            True
# J. Oblak             True
# E. Hazard            True
#                      ...
# Shao Shuai           True
# Xiao Mingjie         True
# Zhang Wei            True
# Wang Haijian         True
# Pan Ximing           True
# Name: height_cm, Length: 18278, dtype: bool

# %%
#
df_jugadores.loc[df_jugadores['height_cm']>170, columnas]
# Out:
#                    age         dob  height_cm  weight_kg nationality  \
# short_name
# Cristiano Ronaldo   34  1985-02-05        187         83    Portugal
# Neymar Jr           27  1992-02-05        175         68      Brazil
# J. Oblak            26  1993-01-07        188         87    Slovenia
# E. Hazard           28  1991-01-07        175         74     Belgium
# K. De Bruyne        28  1991-06-28        181         70     Belgium
# ...                ...         ...        ...        ...         ...
# Shao Shuai          22  1997-03-10        186         79    China PR
# Xiao Mingjie        22  1997-01-01        177         66    China PR
# Zhang Wei           19  2000-05-16        186         75    China PR
# Wang Haijian        18  2000-08-02        185         74    China PR
# Pan Ximing          26  1993-01-11        182         78    China PR
#
#                                             club
# short_name
# Cristiano Ronaldo                       Juventus
# ...

# %%
#Tambien  se pueden combinar condiciones
df_jugadores['height_cm']>170
df_jugadores['nationality'] =='Colombia'
# Out:
# short_name
# L. Messi             False
# Cristiano Ronaldo    False
# Neymar Jr            False
# J. Oblak             False
# E. Hazard            False
#                      ...
# Shao Shuai           False
# Xiao Mingjie         False
# Zhang Wei            False
# Wang Haijian         False
# Pan Ximing           False
# Name: nationality, Length: 18278, dtype: bool

# %%
#Usamos las condiciones anteriores con el metodo &
df_jugadores.loc[
                (df_jugadores['height_cm']>170)
                &
                (df_jugadores['nationality'] =='Colombia'), columnas
                ]
# Out:
#               age         dob  height_cm  weight_kg nationality  \
# short_name
# J. Rodríguez   27  1991-07-12        180         75    Colombia
# D. Sánchez     23  1996-06-12        187         79    Colombia
# Falcao         33  1986-02-10        177         72    Colombia
# J. Cuadrado    31  1988-05-26        179         72    Colombia
# D. Zapata      28  1991-04-01        189         88    Colombia
# ...           ...         ...        ...        ...         ...
# J. Solano      23  1996-02-24        172         68    Colombia
# E. López       19  1999-10-20        178         72    Colombia
# J. Mesa        21  1998-02-23        183         72    Colombia
# D. Ruíz        21  1997-10-02        177         73    Colombia
# J. Rengifo     21  1998-02-27        175         70    Colombia
#
#                            club
# short_name
# J. Rodríguez        Real Madrid
# D. Sánchez    Tottenham Hotspur
# Falcao                AS Monaco
# J. Cuadrado            Juventus
# ...
