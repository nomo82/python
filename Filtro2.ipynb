# %% [markdown]
# <a href="https://colab.research.google.com/github/nomo82/python/blob/main/Filtro2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importar librerias
import pandas as pd
import numpy as np

#Importar el archivo
#Importar el archivo e importarlo a un Data Frame
df_computadores = pd.read_csv('/content/drive/MyDrive/Alexander Niño.lnk/2025/_Python/laptop_price.csv', encoding='ISO-8859-1')

# %%
#Mostrar las primeras coinco columnas
df_computadores.head(5)
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %%
#Traer los precios de los precios
df_computadores['Price_euros']>2000
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 1298    False
# 1299    False
# 1300    False
# 1301    False
# 1302    False
# Name: Price_euros, Length: 1303, dtype: bool

# %%
#Crear un arreglo con where para poder poner lo que deseamos
#Vamos a usar Numpy para traer las condiciones de Where crear un arreglo
np.where(df_computadores['Price_euros'] >2000, 'Cariñoso', 'Ese es')
# Out:
# array(['Ese es', 'Ese es', 'Ese es', ..., 'Ese es', 'Ese es', 'Ese es'],
#       dtype='<U8')

# %%
#Vamos a crear una columna al final llamada 'Testeo' que aprecera al final del DF con la condicion
df_computadores['Testeo']=np.where(df_computadores['Price_euros'] >2000, 'Cariñoso', 'Ese es')
np.where(df_computadores['Price_euros'] >2000, 'Cariñoso', 'Ese es')
# Out:
# array(['Ese es', 'Ese es', 'Ese es', ..., 'Ese es', 'Ese es', 'Ese es'],
#       dtype='<U8')

# %%
#
df_computadores.head(5)
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %%
#Crear una condicion sean mayores a 13"
np.where(df_computadores['Inches'] >13, 'Normal', 'Pequeño')
# Out:
# array(['Normal', 'Normal', 'Normal', ..., 'Normal', 'Normal', 'Normal'],
#       dtype='<U7')

# %%
#Ahora vamos a incluir en el DF al final el tamaño de las pantallas cuales aplican para que sean mayores a 13
df_computadores['Tamaño']=np.where(df_computadores['Inches'] >13, 'Normal', 'Pequeño')

# %%
df_computadores.head(5)
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %%
#Ahora vamos a validar Memoria RAM que contiene Texto si es igual a 16
np.where(df_computadores['Ram']=='16GB', 'Puedes Jugar', 'No puedes Jugar')
# Out:
# array(['No puedes Jugar', 'No puedes Jugar', 'No puedes Jugar', ...,
#        'No puedes Jugar', 'No puedes Jugar', 'No puedes Jugar'],
#       dtype='<U15')

# %%
#Ahoira creamos la columna para validar la Ram
df_computadores['Ram_Juego']=np.where(df_computadores['Ram']=='16GB', 'Puedes Jugar', 'No puedes Jugar')

# %%
#Llamamos nuevamente el DF
df_computadores.head(5)
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...
