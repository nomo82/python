# %% [markdown]
# <a href="https://colab.research.google.com/github/nomo82/python/blob/main/Eliminar_repetidos_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Ahora vanos a ver como eliminar repetidos
#Importar librerias
import pandas as pd
import numpy as np

# %%
#Damos accesoa Google Drive y nos conectamos
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Importar el archivo e importarlo a un Data Frame
df_computadores = pd.read_csv('/content/drive/MyDrive/Alexander Niño.lnk/2025/_Python/laptop_price.csv', encoding='ISO-8859-1')

# %%
df_computadores.head(3)
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
#
#                      ScreenResolution                         Cpu  Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz  8GB
# 1                            1440x900        Intel Core i5 1.8GHz  8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz  8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
#
#    Price_euros
# 0      1339.69
# 1       898.94
# 2       575.00

# %%
#Para eliminar los duplicados vamos a usar el metodo drop_duplicates
df_computadores.drop_duplicates(['Company'])
# Out:
#      laptop_ID    Company                        Product            TypeName  \
# 0            1      Apple                    MacBook Pro           Ultrabook
# 2            3         HP                         250 G6            Notebook
# 5            6       Acer                       Aspire 3            Notebook
# 8            9       Asus                ZenBook UX430UN           Ultrabook
# 13          14       Dell                  Inspiron 3567            Notebook
# 18          19     Lenovo              IdeaPad 320-15IKB            Notebook
# 30          31      Chuwi                  LapBook 15.6"            Notebook
# 58          59        MSI                     GS73VR 7RG              Gaming
# 70          72  Microsoft                 Surface Laptop           Ultrabook
# 143        146    Toshiba                  Satellite Pro            Notebook
# 170        174     Huawei                     MateBook X           Ultrabook
# ...

# %%
#Vamos a ver cuantos elementos quedaron con drop_duplicates
df_computadores.drop_duplicates(['company']).value_counts('Price_euros')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-5fbdf8a80555> in <cell line: 0>()
#       1 #Vamos a ver cuantos elementos quedaron con drop_duplicates
# ----> 2 df_computadores.drop_duplicates(['company']).value_counts('Price_euros')
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop_duplicates(self, subset, keep, inplace, ignore_index)
#    6816         ignore_index = validate_bool_kwarg(ignore_index, "ignore_index")
#    6817
# -> 6818         result = self[-self.duplicated(subset, keep=keep)]
#    6819         if ignore_index:
#    6820             result.index = default_index(len(result))
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in duplicated(self, subset, keep)
#    6948         diff = set(subset) - set(self.columns)
#    6949         if diff:
# -> 6950             raise KeyError(Index(diff))
#    6951
# ...

# %%
df_computadores.drop_duplicates(['Company',])[['Comnpany','Price_euros']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-84c7d1fdd10a> in <cell line: 0>()
# ----> 1 df_computadores.drop_duplicates(['Company',])[['Comnpany','Price_euros']]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
#    6202         keyarr = self.take(indexer)
#
# ...

# %%
df_computadores.drop_duplicates(['Company'], keep='last')[['Company','Price_euros']]
# Out:
#         Company  Price_euros
# 214      Huawei      1499.00
# 483       Chuwi       248.90
# 670   Microsoft      1867.85
# 718    Mediacom       265.00
# 762      Google      1559.00
# 877      Xiaomi       935.00
# 909          LG      1899.00
# 983     Fujitsu       649.00
# 1118    Toshiba      2226.00
# 1120       Vero       196.00
# 1191    Samsung       659.00
# 1231      Razer      3499.00
# 1234      Apple       959.00
# 1259        MSI      1229.00
# 1291       Acer       289.00
# 1295       Dell       805.99
# 1300     Lenovo       229.00
# 1301         HP       764.00
# 1302       Asus       369.00

# %%
#Uso el "implace" para guardar los camnbios en el DF
#Uso el "ignore_index" para ignorar la collumna ID y crear una nueva
df_computadores.drop_duplicates(['Company'], keep='last', inplace=True, ignore_index=True)

# %%
df_computadores
# Out:
#     laptop_ID    Company                              Product  \
# 0         219     Huawei                           MateBook X
# 1         490      Chuwi                         Lapbook 15,6
# 2         678  Microsoft                       Surface Laptop
# 3         726   Mediacom                        Smartbook 142
# 4         771     Google                      Pixelbook (Core
# 5         888     Xiaomi                          Mi Notebook
# 6         922         LG                          Gram 14Z970
# 7         997    Fujitsu                        LifeBook A556
# 8        1133    Toshiba                    Portege X30-D-10K
# 9        1135       Vero     V131 (X5-Z8350/4GB/32GB/FHD/W10)
# 10       1209    Samsung                      Chromebook Plus
# 11       1249      Razer                            Blade Pro
# 12       1252      Apple                          MacBook Air
# 13       1277        MSI                          GE62 Apache
# ...
