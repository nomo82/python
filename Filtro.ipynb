# %% [markdown]
# <a href="https://colab.research.google.com/github/nomo82/python/blob/main/Filtro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importar librerias
import pandas as pd
import numpy as np

# %%
#Importar el archivo e importarlo a un Data Frame
df_computadores = pd.read_csv('/content/drive/MyDrive/Alexander Niño.lnk/2025/_Python/laptop_price.csv', encoding='ISO-8859-1')

# %%
#Llamamos las primeras 5 filas
df_computadores.head(5)
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %%
df_computadores['Company']=='HP'
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 1298    False
# 1299    False
# 1300    False
# 1301     True
# 1302    False
# Name: Company, Length: 1303, dtype: bool

# %%
df_computadores['Company']=='Apple'
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 1298    False
# 1299    False
# 1300    False
# 1301    False
# 1302    False
# Name: Company, Length: 1303, dtype: bool

# %%
df_computadores[df_computadores['Company']=='Apple']
# Out:
#       laptop_ID Company      Product   TypeName  Inches  \
# 0             1   Apple  MacBook Pro  Ultrabook    13.3
# 1             2   Apple  Macbook Air  Ultrabook    13.3
# 3             4   Apple  MacBook Pro  Ultrabook    15.4
# 4             5   Apple  MacBook Pro  Ultrabook    13.3
# 6             7   Apple  MacBook Pro  Ultrabook    15.4
# 7             8   Apple  Macbook Air  Ultrabook    13.3
# 12           13   Apple  MacBook Pro  Ultrabook    15.4
# 14           15   Apple  MacBook 12"  Ultrabook    12.0
# 15           16   Apple  MacBook Pro  Ultrabook    13.3
# 17           18   Apple  MacBook Pro  Ultrabook    15.4
# 26           27   Apple  MacBook Air  Ultrabook    13.3
# 34           35   Apple  MacBook Air  Ultrabook    13.3
# 45           46   Apple  MacBook Pro  Ultrabook    13.3
# 81           83   Apple  MacBook 12"  Ultrabook    12.0
# 249         254   Apple  MacBook Pro  Ultrabook    13.3
# 270         275   Apple  MacBook Pro  Ultrabook    13.3
# ...

# %%
#Filtremos con ASUS
df_computadores['Company']=='Asus'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1298    False
# 1299    False
# 1300    False
# 1301    False
# 1302     True
# Name: Company, Length: 1303, dtype: bool

# %%
df_computadores[df_computadores["Company"]=="Asus"]
# Out:
#       laptop_ID Company                                    Product   TypeName  \
# 8             9    Asus                            ZenBook UX430UN  Ultrabook
# 20           21    Asus                            Vivobook E200HA    Netbook
# 31           32    Asus       E402WA-GA010T (E2-6110/2GB/32GB/W10)   Notebook
# 40           41    Asus  X540UA-DM186 (i3-6006U/4GB/1TB/FHD/Linux)   Notebook
# 42           43    Asus     X542UQ-GO005 (i5-7200U/8GB/1TB/GeForce   Notebook
# ...         ...     ...                                        ...        ...
# 1283       1301    Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce   Notebook
# 1288       1306    Asus        X553SA-XX031T (N3050/4GB/500GB/W10)   Notebook
# 1289       1307    Asus                       ZenBook UX305CA-UBM1  Ultrabook
# 1297       1315    Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce   Notebook
# 1302       1320    Asus        X553SA-XX031T (N3050/4GB/500GB/W10)   Notebook
#
# ...

# %%
#Filtrar
df_computadores[df_computadores['Company']=='Apple'].value_counts['Company']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-21c60596c45d> in <cell line: 0>()
#       1 #Filtrar
# ----> 2 df_computadores[df_computadores['Company']=='Apple'].value_counts['Company']
#
# TypeError: 'method' object is not subscriptable
