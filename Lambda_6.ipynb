# %% [markdown]
# <a href="https://colab.research.google.com/github/nomo82/python/blob/main/Lambda_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#En este caso mezclaremos la funcioan lambda con el método apply
#La función lambda en python es una forma de escribir funciones menos robustas
import pandas as pd
import numpy as np

# %%
#Conectar a Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Traemos el mismo archivo
df_jugadores=pd.read_csv('/content/drive/MyDrive/Alexander Niño.lnk/2025/_Python/players_20.csv')
#Le defino el index
df_jugadores.set_index('short_name', inplace=True)
#Selecciono las columnas que voy a usar
df_jugadores= df_jugadores[['player_url','long_name', 'age',  'dob',  'height_cm',  'weight_kg',  'nationality',  'club']]
df_jugadores.head(5)
# Out:
#                                                           player_url  \
# short_name
# L. Messi           https://sofifa.com/player/158023/lionel-messi/...
# Cristiano Ronaldo  https://sofifa.com/player/20801/c-ronaldo-dos-...
# Neymar Jr          https://sofifa.com/player/190871/neymar-da-sil...
# J. Oblak           https://sofifa.com/player/200389/jan-oblak/20/...
# E. Hazard          https://sofifa.com/player/183277/eden-hazard/2...
#
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
#
#                    height_cm  weight_kg nationality                 club
# short_name
# ...

# %%
#Las funciones normalmente se ven de la siguiente manera
def sumar(a, b):
  x=a+b
  return (x)

# %%
sumar(29,24)
# Out:
# 53

# %%
from binascii import b2a_base64
def modulo(a,b):
  y=a%b
  return (y)

# %%
modulo(25,2)
# Out:
# 1

# %%
#Vamos a ver como se hace las funciones usando lambda
#Primero se asigna el nombre luego asignamos el valor, luego introducimos los parametros, luego dos puntos y por ultimo el output
sumar_2=lambda a,b: a+b

# %%
sumar_2(39,39)
# Out:
# 78

# %%
modulo_2=lambda a,b: a%b

# %%
modulo_2(48,2)
# Out:
# 0

# %%
df_jugadores.head(3)
# Out:
#                                                           player_url  \
# short_name
# L. Messi           https://sofifa.com/player/158023/lionel-messi/...
# Cristiano Ronaldo  https://sofifa.com/player/20801/c-ronaldo-dos-...
# Neymar Jr          https://sofifa.com/player/190871/neymar-da-sil...
#
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
#
#                    height_cm  weight_kg nationality                 club
# short_name
# L. Messi                 170         72   Argentina         FC Barcelona
# Cristiano Ronaldo        187         83    Portugal             Juventus
# Neymar Jr                175         68      Brazil  Paris Saint-Germain

# %%
#Ahora usemos a apply con lamba
#Vamosa a pasar los cm a mtros en la información de los jugadores
#En este caso si usamos apply no necesitamos poner el nombre de la función
df_jugadores['height_cm'].apply(lambda x:x/100)
# Out:
# short_name
# L. Messi             1.70
# Cristiano Ronaldo    1.87
# Neymar Jr            1.75
# J. Oblak             1.88
# E. Hazard            1.75
#                      ...
# Shao Shuai           1.86
# Xiao Mingjie         1.77
# Zhang Wei            1.86
# Wang Haijian         1.85
# Pan Ximing           1.82
# Name: height_cm, Length: 18278, dtype: float64

# %%
#Ahora vamos a determinar la edad en meses
df_jugadores['age']/12
# Out:
# short_name
# L. Messi             2.666667
# Cristiano Ronaldo    2.833333
# Neymar Jr            2.250000
# J. Oblak             2.166667
# E. Hazard            2.333333
#                        ...
# Shao Shuai           1.833333
# Xiao Mingjie         1.833333
# Zhang Wei            1.583333
# Wang Haijian         1.500000
# Pan Ximing           2.166667
# Name: age, Length: 18278, dtype: float64

# %%
#Ahora vamos a determinar de cm a m
df_jugadores['height_cm']/100
# Out:
# short_name
# L. Messi             1.70
# Cristiano Ronaldo    1.87
# Neymar Jr            1.75
# J. Oblak             1.88
# E. Hazard            1.75
#                      ...
# Shao Shuai           1.86
# Xiao Mingjie         1.77
# Zhang Wei            1.86
# Wang Haijian         1.85
# Pan Ximing           1.82
# Name: height_cm, Length: 18278, dtype: float64

# %%
#Colocar los nombres en mayusculas
df_jugadores['long_name'] = df_jugadores['long_name'].apply(lambda x: x.upper())

# %%
#Hacerlo simple pero com mas memoriaseria asi
df_jugadores['long_name'].str.upper()
# Out:
# short_name
# L. Messi                  LIONEL ANDRÉS MESSI CUCCITTINI
# Cristiano Ronaldo    CRISTIANO RONALDO DOS SANTOS AVEIRO
# Neymar Jr                  NEYMAR DA SILVA SANTOS JUNIOR
# J. Oblak                                       JAN OBLAK
# E. Hazard                                    EDEN HAZARD
#                                     ...
# Shao Shuai                                            邵帅
# Xiao Mingjie                                MINGJIE XIAO
# Zhang Wei                                             张威
# Wang Haijian                                         汪海健
# Pan Ximing                                           潘喜明
# Name: long_name, Length: 18278, dtype: object

# %%
#Tambien puedo usar landa para extraer poarte de fechas
#Primero dedemos garantizar que el dato fecha este en modo DATE
df_jugadores['dob']=pd.to_datetime(df_jugadores['dob'])

# %%
#Ahora soilo extraemos los años con la funcion lambda
df_jugadores['dob'].apply(lambda x:x.year)
# Out:
# short_name
# L. Messi             1987
# Cristiano Ronaldo    1985
# Neymar Jr            1992
# J. Oblak             1993
# E. Hazard            1991
#                      ...
# Shao Shuai           1997
# Xiao Mingjie         1997
# Zhang Wei            2000
# Wang Haijian         2000
# Pan Ximing           1993
# Name: dob, Length: 18278, dtype: int64

# %%
#Ahora solo extraer los meses con la funcion lambda
df_jugadores['dob'].apply(lambda x: x.month_name())
# Out:
# short_name
# L. Messi                 June
# Cristiano Ronaldo    February
# Neymar Jr            February
# J. Oblak              January
# E. Hazard             January
#                        ...
# Shao Shuai              March
# Xiao Mingjie          January
# Zhang Wei                 May
# Wang Haijian           August
# Pan Ximing            January
# Name: dob, Length: 18278, dtype: object

# %%
#Índice de Masa Corporal (IMC) usando lambda en pandas. La fórmula es:
#Formula: 𝐼𝑀𝐶 = peso (kg) / altura (m)2
df_jugadores['IMC'] = df_jugadores.apply(lambda x:x['weight_kg'] / ((x['height_cm'] / 100) ** 2), axis=1)
df_jugadores
# Out:
#                                                           player_url  \
# short_name
# L. Messi           https://sofifa.com/player/158023/lionel-messi/...
# Cristiano Ronaldo  https://sofifa.com/player/20801/c-ronaldo-dos-...
# Neymar Jr          https://sofifa.com/player/190871/neymar-da-sil...
# J. Oblak           https://sofifa.com/player/200389/jan-oblak/20/...
# E. Hazard          https://sofifa.com/player/183277/eden-hazard/2...
# ...                                                              ...
# Shao Shuai         https://sofifa.com/player/245006/shuai-shao/20...
# Xiao Mingjie       https://sofifa.com/player/250995/mingjie-xiao/...
# Zhang Wei          https://sofifa.com/player/252332/wei-zhang/20/...
# Wang Haijian       https://sofifa.com/player/251110/haijian-wang/...
# Pan Ximing         https://sofifa.com/player/233449/ximing-pan/20...
#
#                                              long_name  age        dob  \
# short_name
# ...
