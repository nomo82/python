# %% [markdown]
# <a href="https://colab.research.google.com/github/nomo82/python/blob/main/Extraccion_2_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Usaremos el metodo "iloc"
#importamos librerias

# %%
#Importar librerias Pandas
import pandas as pd

# %%
#Conectar a Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Leer el archivo CSV palyers 20.csv
df_jugadores=pd.read_csv('/content/drive/MyDrive/Alexander Niño.lnk/2025/_Python/players_20.csv')
df_jugadores.head(10)
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
# 5     192985  https://sofifa.com/player/192985/kevin-de-bruy...
# 6     192448  https://sofifa.com/player/192448/marc-andre-te...
# 7     203376  https://sofifa.com/player/203376/virgil-van-di...
# 8     177003  https://sofifa.com/player/177003/luka-modric/2...
# 9     209331  https://sofifa.com/player/209331/mohamed-salah...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# ...

# %%
#Vamos a traer las columnas que necesito y voy actualizar el DF
df_jugadores=df_jugadores[['player_url', 'long_name',	'age', 'dob',	'height_cm',	'weight_kg', 'nationality',	'club']]
df_jugadores
# Out:
#                                               player_url  \
# 0      https://sofifa.com/player/158023/lionel-messi/...
# 1      https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2      https://sofifa.com/player/190871/neymar-da-sil...
# 3      https://sofifa.com/player/200389/jan-oblak/20/...
# 4      https://sofifa.com/player/183277/eden-hazard/2...
# ...                                                  ...
# 18273  https://sofifa.com/player/245006/shuai-shao/20...
# 18274  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276  https://sofifa.com/player/251110/haijian-wang/...
# 18277  https://sofifa.com/player/233449/ximing-pan/20...
#
#                                  long_name  age         dob  height_cm  \
# 0           Lionel Andrés Messi Cuccittini   32  1987-06-24        170
# 1      Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05        187
# ...

# %%
df_jugadores=df_jugadores.set_index('short_name')
df_jugadores.head(3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-87acb297ab87> in <cell line: 0>()
# ----> 1 df_jugadores=df_jugadores.set_index('short_name')
#       2 df_jugadores.head(3)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#
# KeyError: "None of ['short_name'] are in the columns"

# %%
df_jugadores.iloc[1, 4]
# Out:
# 187

# %%
#Para obtener el dato del club de Neymar Jr
df_jugadores.iloc[2, 7]
# Out:
# 'Paris Saint-Germain'

# %%
#Para traer el nombre complero de todos los jugadores lo haria de la siguiente manera
df_jugadores.iloc[ :, 1]
# Out:
# 0             Lionel Andrés Messi Cuccittini
# 1        Cristiano Ronaldo dos Santos Aveiro
# 2              Neymar da Silva Santos Junior
# 3                                  Jan Oblak
# 4                                Eden Hazard
#                         ...
# 18273                                     邵帅
# 18274                           Mingjie Xiao
# 18275                                     张威
# 18276                                    汪海健
# 18277                                    潘喜明
# Name: long_name, Length: 18278, dtype: object

# %%
#Traer la lacionalidad de todos
df_jugadores.iloc[ :, 6]
# Out:
# 0        Argentina
# 1         Portugal
# 2           Brazil
# 3         Slovenia
# 4          Belgium
#            ...
# 18273     China PR
# 18274     China PR
# 18275     China PR
# 18276     China PR
# 18277     China PR
# Name: nationality, Length: 18278, dtype: object

# %%
#Traer solo los datos de Jan Oblak
df_jugadores.iloc[3, :]
# Out:
# player_url     https://sofifa.com/player/200389/jan-oblak/20/...
# long_name                                              Jan Oblak
# age                                                           26
# dob                                                   1993-01-07
# height_cm                                                    188
# weight_kg                                                     87
# nationality                                             Slovenia
# club                                             Atlético Madrid
# Name: 3, dtype: object

# %%
#Traer solo los datos del último de la lista
df_jugadores.iloc[-1, :]
# Out:
# player_url     https://sofifa.com/player/233449/ximing-pan/20...
# long_name                                                    潘喜明
# age                                                           26
# dob                                                   1993-01-11
# height_cm                                                    182
# weight_kg                                                     78
# nationality                                             China PR
# club                                      Hebei China Fortune FC
# Name: 18277, dtype: object

# %%
#Traer los datos completos de Cristianos Ronaldo y Messi
df_jugadores.iloc[[0,1], [:]]
# Out:
#   File "<ipython-input-40-b2acb2ba4511>", line 2
#     df_jugadores.iloc[[0,1], [:]]
#                               ^
# SyntaxError: invalid syntax

# %%
#Traer el peso y la estatura de Neymar Jr
df_jugadores.iloc [2,[4,5]]
# Out:
# height_cm    175
# weight_kg     68
# Name: 2, dtype: object

# %%
df_jugadores.iloc[[0,1],[4,5]]
# Out:
#    height_cm  weight_kg
# 0        170         72
# 1        187         83

# %%
#Traer los datos desde Cristiano age hasta el final
jugadores=[0,1]
df_jugadores.iloc[jugadores, 3:]
# Out:
#           dob  height_cm  weight_kg nationality          club
# 0  1987-06-24        170         72   Argentina  FC Barcelona
# 1  1985-02-05        187         83    Portugal      Juventus

# %%
#Traer los datos de los jugadores Top 10
df_jugadores.iloc[:10]
# Out:
#                                           player_url  \
# 0  https://sofifa.com/player/158023/lionel-messi/...
# 1  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2  https://sofifa.com/player/190871/neymar-da-sil...
# 3  https://sofifa.com/player/200389/jan-oblak/20/...
# 4  https://sofifa.com/player/183277/eden-hazard/2...
# 5  https://sofifa.com/player/192985/kevin-de-bruy...
# 6  https://sofifa.com/player/192448/marc-andre-te...
# 7  https://sofifa.com/player/203376/virgil-van-di...
# 8  https://sofifa.com/player/177003/luka-modric/2...
# 9  https://sofifa.com/player/209331/mohamed-salah...
#
#                              long_name  age         dob  height_cm  weight_kg  \
# 0       Lionel Andrés Messi Cuccittini   32  1987-06-24        170         72
# 1  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05        187         83
# 2        Neymar da Silva Santos Junior   27  1992-02-05        175         68
# ...
