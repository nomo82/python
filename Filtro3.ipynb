# %% [markdown]
# <a href="https://colab.research.google.com/github/nomo82/python/blob/main/Filtro3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Tambien puedo filtrar por mas condiciones y lo puedo ghacer con and o or depende del caso
#Importar librerias
import pandas as pd
import numpy as np

#Conectarse e importar el archivoi desde Google Drive
#Importar el archivo e importarlo a un Data Frame
df_computadores = pd.read_csv('/content/drive/MyDrive/Alexander Niño.lnk/2025/_Python/laptop_price.csv', encoding='ISO-8859-1')

# %%
#Damos accesoa Google Drive y nos conectamos
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Traemos los primeros 5 datos de DF
df_computadores.head(5)
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %%
#Filtramos 'Price_euros' que sea mayor a 2000
df_computadores['Price_euros']>2000
df_computadores
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
#Filtramos por Apple
df_computadores['Company']=='Apple'
df_computadores
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
#Si deseo filtrar pos las dos condiciones anteriormente ejecutadas
#Que sea mayor a 2000 y que sea Apple debo usar AND o O
#AND en pandas es '&' y en pandas O es '|'
(df_computadores['Company']=='Apple') & (df_computadores['Price_euros']>2000)
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 1298    False
# 1299    False
# 1300    False
# 1301    False
# 1302    False
# Length: 1303, dtype: bool

# %%
df_computadores[(df_computadores['Company']=='Apple') & (df_computadores['Price_euros']>2000)]
# Out:
#      laptop_ID Company      Product   TypeName  Inches  \
# 3            4   Apple  MacBook Pro  Ultrabook    15.4
# 6            7   Apple  MacBook Pro  Ultrabook    15.4
# 12          13   Apple  MacBook Pro  Ultrabook    15.4
# 17          18   Apple  MacBook Pro  Ultrabook    15.4
# 249        254   Apple  MacBook Pro  Ultrabook    13.3
#
#                        ScreenResolution                   Cpu   Ram  \
# 3    IPS Panel Retina Display 2880x1800  Intel Core i7 2.7GHz  16GB
# 6    IPS Panel Retina Display 2880x1800  Intel Core i7 2.2GHz  16GB
# 12   IPS Panel Retina Display 2880x1800  Intel Core i7 2.8GHz  16GB
# 17   IPS Panel Retina Display 2880x1800  Intel Core i7 2.9GHz  16GB
# 249  IPS Panel Retina Display 2560x1600  Intel Core i5 3.1GHz   8GB
#
#                   Memory                           Gpu     OpSys  Weight  \
# 3              512GB SSD            AMD Radeon Pro 455     macOS  1.83kg
# 6    256GB Flash Storage       Intel Iris Pro Graphics  Mac OS X  2.04kg
# ...

# %%
#Ahora filtrar que sea DELL y que sea menor a 1000
(df_computadores['Company']=='Dell') & (df_computadores['Price_euros']<1000)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1298    False
# 1299    False
# 1300    False
# 1301    False
# 1302    False
# Length: 1303, dtype: bool

# %%
df_computadores[(df_computadores['Company']=='Dell') & (df_computadores['Price_euros']<1000)]
# Out:
#       laptop_ID Company        Product            TypeName  Inches  \
# 13           14    Dell  Inspiron 3567            Notebook    15.6
# 16           17    Dell  Inspiron 3567            Notebook    15.6
# 19           20    Dell         XPS 13           Ultrabook    13.3
# 23           24    Dell  Inspiron 5379  2 in 1 Convertible    13.3
# 25           26    Dell  Inspiron 3567            Notebook    15.6
# ...         ...     ...            ...                 ...     ...
# 1278       1296    Dell  Inspiron 3552            Notebook    15.6
# 1281       1299    Dell  Inspiron 3567            Notebook    15.6
# 1290       1308    Dell  Inspiron 3567            Notebook    15.6
# 1292       1310    Dell  Inspiron 3552            Notebook    15.6
# 1295       1313    Dell  Inspiron 3567            Notebook    15.6
#
#                                ScreenResolution  \
# 13                            Full HD 1920x1080
# 16                            Full HD 1920x1080
# ...

# %%
#Ahora vamos a ver el ejemplo con O '|'
#Realizamo el ejemplo con Apple
df_computadores[(df_computadores['Company']=='Apple') | (df_computadores['Price_euros']>2000)]
# Out:
#       laptop_ID Company        Product   TypeName  Inches  \
# 0             1   Apple    MacBook Pro  Ultrabook    13.3
# 1             2   Apple    Macbook Air  Ultrabook    13.3
# 3             4   Apple    MacBook Pro  Ultrabook    15.4
# 4             5   Apple    MacBook Pro  Ultrabook    13.3
# 6             7   Apple    MacBook Pro  Ultrabook    15.4
# ...         ...     ...            ...        ...     ...
# 1210       1228   Apple    MacBook 12"  Ultrabook    12.0
# 1231       1249   Razer      Blade Pro     Gaming    14.0
# 1234       1252   Apple    MacBook Air  Ultrabook    11.6
# 1236       1254      HP  EliteBook 840  Ultrabook    14.0
# 1247       1265    Asus    Rog GL502VS     Gaming    15.6
#
#                         ScreenResolution                          Cpu   Ram  \
# 0     IPS Panel Retina Display 2560x1600         Intel Core i5 2.3GHz   8GB
# 1                               1440x900         Intel Core i5 1.8GHz   8GB
# ...

# %%
#Ahora lo vamos a filtrar por las compañias que cumplen con estos criterios
df_computadores[(df_computadores['Company']=='Apple') | (df_computadores['Price_euros']>2000)].value_counts('Company')
# Out:
# Company
# Dell         34
# Lenovo       32
# Apple        21
# HP           20
# MSI          19
# Asus         14
# Razer         5
# Acer          2
# LG            2
# Toshiba       2
# Google        1
# Microsoft     1
# Name: count, dtype: int64

# %%
df_computadores[(df_computadores['Company']=='Dell') | (df_computadores['Price_euros']<1000)].value_counts('Company')
# Out:
# Company
# Dell         297
# Lenovo       169
# HP           144
# Acer          96
# Asus          79
# Toshiba       13
# Mediacom       7
# Vero           4
# Apple          3
# Chuwi          3
# Fujitsu        3
# MSI            2
# Samsung        2
# Xiaomi         2
# Microsoft      1
# Name: count, dtype: int64

# %%
#Vamlmos a filtrar por computadores que sean Apple o Asus. Que cuesten menos de 2000
df_computadores[
    ((df_computadores['Company'] == 'Apple') | (df_computadores['Company'] == 'Asus')) &
    (df_computadores['Price_euros'] < 2000)
]
# Out:
#       laptop_ID Company                                    Product   TypeName  \
# 0             1   Apple                                MacBook Pro  Ultrabook
# 1             2   Apple                                Macbook Air  Ultrabook
# 4             5   Apple                                MacBook Pro  Ultrabook
# 7             8   Apple                                Macbook Air  Ultrabook
# 8             9    Asus                            ZenBook UX430UN  Ultrabook
# ...         ...     ...                                        ...        ...
# 1283       1301    Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce   Notebook
# 1288       1306    Asus        X553SA-XX031T (N3050/4GB/500GB/W10)   Notebook
# 1289       1307    Asus                       ZenBook UX305CA-UBM1  Ultrabook
# 1297       1315    Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce   Notebook
# 1302       1320    Asus        X553SA-XX031T (N3050/4GB/500GB/W10)   Notebook
#
# ...

# %%
#Vamlmos a filtrar por computadores que Apple. Que cuesten menos de 2000 y que sean mas de 13"
df_computadores [
    ((df_computadores['Company']=='Apple') | (df_computadores['Price_euros']<2000)) &
    df_computadores['Inches']='13')
]
# Out:
#   File "<ipython-input-20-61f78215071c>", line 4
#     df_computadores['Inches']='13'
#                              ^
# SyntaxError: invalid syntax
