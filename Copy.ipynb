# %% [markdown]
# <a href="https://colab.research.google.com/github/nomo82/python/blob/main/Copy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Ahora lo que vamos a realizar es copiar un DF en otro lado
import pandas as pd
import numpy as np

# %%
#Conectar a Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Traemos el mismo archivo
df_jugadores=pd.read_csv('/content/drive/MyDrive/Alexander Niño.lnk/2025/_Python/players_20.csv')
#Le defino el index
df_jugadores.set_index('short_name', inplace=True)
#Selecciono las columnas que voy a usar
df_jugadores= df_jugadores[['player_url','long_name', 'age',  'dob',  'height_cm',  'weight_kg',  'nationality',  'club']]
df_jugadores.head(5)
# Out:
#                                                           player_url  \
# short_name
# L. Messi           https://sofifa.com/player/158023/lionel-messi/...
# Cristiano Ronaldo  https://sofifa.com/player/20801/c-ronaldo-dos-...
# Neymar Jr          https://sofifa.com/player/190871/neymar-da-sil...
# J. Oblak           https://sofifa.com/player/200389/jan-oblak/20/...
# E. Hazard          https://sofifa.com/player/183277/eden-hazard/2...
#
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
#
#                    height_cm  weight_kg nationality                 club
# short_name
# ...

# %%
#Asi creo una copia sin dependencias
df_jugadores_1=df_jugadores.copy()

# %%
#Vamos a realizar un cambio en el DF original y lo comparamos con el DF Original
df_jugadores.loc['L. Messi', 'weight_kg']=92
df_jugadores.head(1)
# Out:
#                                                    player_url  \
# short_name
# L. Messi    https://sofifa.com/player/158023/lionel-messi/...
#
#                                  long_name  age         dob  height_cm  \
# short_name
# L. Messi    Lionel Andrés Messi Cuccittini   32  1987-06-24        170
#
#             weight_kg nationality          club
# short_name
# L. Messi           92   Argentina  FC Barcelona

# %%
#Comparamos los datos de 'weight_kg' y son diferentes en cada DF
df_jugadores_1.head(1)
# Out:
#                                                    player_url  \
# short_name
# L. Messi    https://sofifa.com/player/158023/lionel-messi/...
#
#                                  long_name  age         dob  height_cm  \
# short_name
# L. Messi    Lionel Andrés Messi Cuccittini   32  1987-06-24        170
#
#             weight_kg nationality          club
# short_name
# L. Messi           72   Argentina  FC Barcelona
