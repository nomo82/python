# %% [markdown]
# <a href="https://colab.research.google.com/github/nomo82/python/blob/main/Filtro4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Tambien puedo filtrar por mas condiciones y lo puedo ghacer con and o or depende del caso
#Importar librerias
import pandas as pd
import numpy as np

#Conectarse e importar el archivoi desde Google Drive
#Importar el archivo e importarlo a un Data Frame
df_computadores = pd.read_csv('/content/drive/MyDrive/Alexander Niño.lnk/2025/_Python/laptop_price.csv', encoding='ISO-8859-1')

# %%
#Damos accesoa Google Drive y nos conectamos
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_computadores.head(5)
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %%
df_computadores["Testeo_2"]=np.select(condiciones,valores)
df_computadores
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
condiciones = [
    df_computadores['Price_euros'] > 3000,
    (df_computadores['Price_euros'] > 2000) & (df_computadores['Price_euros'] <= 3000),
    (df_computadores['Price_euros'] > 800) & (df_computadores['Price_euros'] <= 2000),
    df_computadores['Price_euros'] <= 800
]

valores = ['Carisimo', 'Puede ser mejor', 'Esta Mejor', 'Muy Barato']

# %%
np.select(condiciones,valores)
# Out:
# array(['Esta Mejor', 'Esta Mejor', 'Muy Barato', ..., 'Muy Barato',
#        'Muy Barato', 'Muy Barato'], dtype='<U15')

# %%
df_computadores.value_counts('Testeo_2')
# Out:
# Testeo_2
# Esta Mejor         655
# Muy Barato         511
# Puede ser mejor    118
# Carisimo            19
# Name: count, dtype: int64
